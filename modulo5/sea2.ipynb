# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import yfinance as yf

# %%
Base_Dados = pd.read_csv('../Pandas/StudentsPerformance.csv')

# %%
sns.lineplot(data=Base_Dados, y='math score', x='race/ethnicity', err_style=None)
# Out:
# <AxesSubplot:xlabel='race/ethnicity', ylabel='math score'>

# %%
sns.lineplot(data=Base_Dados, y='math score', x='race/ethnicity', hue='gender')
# Out:
# <AxesSubplot:xlabel='race/ethnicity', ylabel='math score'>

# %%
mag = yf.Ticker('MGLU3.SA').history(period='max')

# %%
mag
# Out:
#                 Open      High       Low     Close     Volume  Dividends  \
# Date
# 2011-05-02  0.453318  0.467397  0.453318  0.463173  280003200        0.0
# 2011-05-03  0.464581  0.469930  0.456134  0.458950   33670400        0.0
# 2011-05-04  0.459513  0.464018  0.459513  0.464018   39203200        0.0
# 2011-05-05  0.462047  0.462047  0.459513  0.461202   35097600        0.0
# 2011-05-06  0.460357  0.461202  0.450503  0.457823   38672000        0.0
# ...              ...       ...       ...       ...        ...        ...
# 2022-07-07  2.560000  2.650000  2.430000  2.560000  196227300        0.0
# 2022-07-08  2.530000  2.650000  2.460000  2.620000  152161400        0.0
# 2022-07-11  2.550000  2.690000  2.510000  2.630000  156371900        0.0
# 2022-07-12  2.650000  3.030000  2.620000  2.930000  328802300        0.0
# 2022-07-13  2.870000  2.980000  2.810000  2.830000  287592000        0.0
#
#             Stock Splits
# Date
# 2011-05-02           0.0
# 2011-05-03           0.0
# ...

# %%
sns.lineplot(data=mag, x='Date', y='Close')
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Close'>

# %%
sns.heatmap(Base_Dados.corr(),cmap='magma_r', annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(Base_Dados.groupby('parental level of education').mean(),cmap='magma_r', annot=True)
# Out:
# <AxesSubplot:ylabel='parental level of education'>
