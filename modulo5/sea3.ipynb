# %%
import sys
sys.path.insert(0, '../')
import bibliotecas as lib
from bibliotecas import base_estudantes, job, magalu, alunos, petrobras

# %%
base = base_estudantes()

# %%
lib.sns.histplot(data=base, x='math score')
# Out:
# <AxesSubplot:xlabel='math score', ylabel='Count'>

# %%
lib.sns.histplot(data=base, x='math score', kde=True)
# Out:
# <AxesSubplot:xlabel='math score', ylabel='Count'>

# %%
lib.sns.histplot(data=base, x='math score', hue='gender')
# Out:
# <AxesSubplot:xlabel='math score', ylabel='Count'>

# %%
lib.sns.histplot(data=base, x='math score', kde=True, element='poly')
# Out:
# <AxesSubplot:xlabel='math score', ylabel='Count'>

# %%
lib.sns.pairplot(data=base)

# %%
lib.sns.pairplot(data=base, corner=True)

# %%
lib.sns.jointplot(data=base)

# %%
lib.sns.jointplot(data=base, x='math score', y='reading score')

# %%
lib.sns.lmplot(data=base, x='math score', y='reading score') #reta da regrssao

# %%
lib.sns.lmplot(data=base, x='math score', y='reading score', hue='gender')

# %%
lib.sns.lmplot(data=base, x='math score', y='reading score', col='gender')

# %%
lib.sns.lmplot(data=base, x='math score', y='reading score', hue='gender', col='race/ethnicity')

# %%
lib.sns.lmplot(data=base, x='math score', y='reading score', hue='gender', col='race/ethnicity', col_wrap=2)
