# %%
import pandas as pd
import numpy as np

# %%
np.random.seed(10)
n = 50_000

escolaridade = ['Ensino Fundamental', 'Ensino Médio', 'Ensino Superior']

data = {
    'Id': np.arange(1, n+1),
    'Idade': np.random.randint(18, 70, size = n),
    'Renda': np.random.randint(1_500, 10_000, size = n),
    'Sexo': np.random.choice(['Masculino', 'Feminino'], size = n),
    'Escolaridade': np.random.choice(escolaridade, size = n)
}

df = pd.DataFrame(data)

# %%
np.random.seed(7)
ativos = pd.Series(np.random.normal(3_000, 1000, size = n)).round(2)

# %%
# cria coluna de ativos
df['ativo'] = ativos

# %%
# cria coluna de renda total
df['renda_total'] = df['Renda']+df['ativo']

# %%
# renda média (ativos e renda)
renda_media = df.loc[:, ['Renda', 'ativo']].mean(axis = 1)

# %%
# posição da coluna 'ativo'
posicao = df.columns.to_list().index('ativo')

# %%
# insere a coluna renda_media na posição da coluna 'ativo'
df.insert(posicao, 'renda_média', renda_media )

# %%
df
# Out:
#           Id  Idade  Renda       Sexo        Escolaridade  renda_média  \
# 0          1     27   2554   Feminino  Ensino Fundamental     3622.265
# 1          2     54   2475   Feminino     Ensino Superior     2504.530
# 2          3     33   6820  Masculino     Ensino Superior     4926.410
# 3          4     18   2141  Masculino        Ensino Médio     2774.260
# 4          5     67   7381  Masculino  Ensino Fundamental     4796.040
# ...      ...    ...    ...        ...                 ...          ...
# 49995  49996     41   3102   Feminino     Ensino Superior     2232.080
# 49996  49997     33   3906   Feminino     Ensino Superior     3629.200
# 49997  49998     41   2543  Masculino     Ensino Superior     2894.955
# 49998  49999     22   4651   Feminino     Ensino Superior     3972.110
# 49999  50000     22   2131   Feminino     Ensino Superior     2583.720
#
#          ativo  renda_total
# 0      4690.53      7244.53
# 1      2534.06      5009.06
# 2      3032.82      9852.82
# 3      3407.52      5548.52
# 4      2211.08      9592.08
# ...        ...          ...
# 49995  1362.16      4464.16
# 49996  3352.40      7258.40
# 49997  3246.91      5789.91
# 49998  3293.22      7944.22
# 49999  3036.44      5167.44
#
# [50000 rows x 8 columns]

# %% [markdown]
# ### Funções úteis

# %%
df.head()
# Out:
#    Id  Idade  Renda       Sexo        Escolaridade  renda_média    ativo  \
# 0   1     27   2554   Feminino  Ensino Fundamental     3622.265  4690.53
# 1   2     54   2475   Feminino     Ensino Superior     2504.530  2534.06
# 2   3     33   6820  Masculino     Ensino Superior     4926.410  3032.82
# 3   4     18   2141  Masculino        Ensino Médio     2774.260  3407.52
# 4   5     67   7381  Masculino  Ensino Fundamental     4796.040  2211.08
#
#    renda_total
# 0      7244.53
# 1      5009.06
# 2      9852.82
# 3      5548.52
# 4      9592.08

# %% [markdown]
# sample(): amostra aleatória

# %%
# amostra aleatória
df.sample(10, random_state = 1)
# Out:
#           Id  Idade  Renda       Sexo        Escolaridade  renda_média  \
# 26247  26248     43   2495  Masculino        Ensino Médio     2781.515
# 35067  35068     21   3740   Feminino  Ensino Fundamental     3650.095
# 34590  34591     30   5805  Masculino        Ensino Médio     3939.060
# 16668  16669     63   1886   Feminino        Ensino Médio     2379.710
# 12196  12197     48   7285   Feminino        Ensino Médio     4789.580
# 2600    2601     68   7918  Masculino        Ensino Médio     5455.850
# 9047    9048     52   9254   Feminino  Ensino Fundamental     5938.710
# 2206    2207     35   7972   Feminino        Ensino Médio     4394.900
# 25607  25608     19   9115   Feminino     Ensino Superior     6210.805
# 11606  11607     66   4097  Masculino     Ensino Superior     3115.520
#
#          ativo  renda_total
# 26247  3068.03      5563.03
# 35067  3560.19      7300.19
# 34590  2073.12      7878.12
# 16668  2873.42      4759.42
# 12196  2294.16      9579.16
# 2600   2993.70     10911.70
# 9047   2623.42     11877.42
# 2206    817.80      8789.80
# 25607  3306.61     12421.61
# 11606  2134.04      6231.04

# %% [markdown]
# transpose(): tranposição dos dados

# %%
df.head().T
# Out:
#                                0                1                2  \
# Id                             1                2                3
# Idade                         27               54               33
# Renda                       2554             2475             6820
# Sexo                    Feminino         Feminino        Masculino
# Escolaridade  Ensino Fundamental  Ensino Superior  Ensino Superior
# renda_média              3622.26          2504.53          4926.41
# ativo                    4690.53          2534.06          3032.82
# renda_total              7244.53          5009.06          9852.82
#
#                          3                   4
# Id                       4                   5
# Idade                   18                  67
# Renda                 2141                7381
# Sexo             Masculino           Masculino
# Escolaridade  Ensino Médio  Ensino Fundamental
# renda_média        2774.26             4796.04
# ativo              3407.52             2211.08
# renda_total        5548.52             9592.08

# %%
df.sample(5).T
# Out:
#                            1661             4590             38755  \
# Id                          1662             4591            38756
# Idade                         31               53               64
# Renda                       3352             2060             3507
# Sexo                   Masculino        Masculino         Feminino
# Escolaridade  Ensino Fundamental  Ensino Superior  Ensino Superior
# renda_média              3186.86          1906.43          3218.86
# ativo                    3021.73          1752.86          2930.71
# renda_total              6373.73          3812.86          6437.71
#
#                         31026               1641
# Id                      31027                1642
# Idade                      37                  49
# Renda                    6656                9053
# Sexo                 Feminino           Masculino
# Escolaridade  Ensino Superior  Ensino Fundamental
# renda_média           4482.33             6502.74
# ativo                 2308.66             3952.48
# renda_total           8964.66             13005.5

# %%
df.sample(5).transpose()
# Out:
#                            9924             45050            13658  \
# Id                          9925            45051            13659
# Idade                         68               31               40
# Renda                       6238             2264             8457
# Sexo                    Feminino        Masculino        Masculino
# Escolaridade  Ensino Fundamental  Ensino Superior  Ensino Superior
# renda_média              5095.62          3197.88          6010.27
# ativo                    3953.24          4131.75          3563.55
# renda_total              10191.2          6395.75          12020.5
#
#                            33288         29541
# Id                         33289         29542
# Idade                         66            47
# Renda                       2182          7808
# Sexo                   Masculino      Feminino
# Escolaridade  Ensino Fundamental  Ensino Médio
# renda_média              2745.85       6158.39
# ativo                    3309.69       4508.78
# renda_total              5491.69       12316.8

# %% [markdown]
# select_dtypes(): seleciona colunas a partir do dtype (return a subset of the DataFrame's columns based on the column dtypes)

# %%
df.dtypes
# Out:
# Id                int64
# Idade             int64
# Renda             int64
# Sexo             object
# Escolaridade     object
# renda_média     float64
# ativo           float64
# renda_total     float64
# dtype: object

# %%
pd.get_dummies(df.select_dtypes(object))
# Out:
#        Sexo_Feminino  Sexo_Masculino  Escolaridade_Ensino Fundamental  \
# 0                  1               0                                1
# 1                  1               0                                0
# 2                  0               1                                0
# 3                  0               1                                0
# 4                  0               1                                1
# ...              ...             ...                              ...
# 49995              1               0                                0
# 49996              1               0                                0
# 49997              0               1                                0
# 49998              1               0                                0
# 49999              1               0                                0
#
#        Escolaridade_Ensino Médio  Escolaridade_Ensino Superior
# 0                              0                             0
# 1                              0                             1
# 2                              0                             1
# 3                              1                             0
# 4                              0                             0
# ...                          ...                           ...
# 49995                          0                             1
# 49996                          0                             1
# 49997                          0                             1
# 49998                          0                             1
# 49999                          0                             1
#
# [50000 rows x 5 columns]

# %%
df.select_dtypes(int)
# Out:
#           Id  Idade  Renda
# 0          1     27   2554
# 1          2     54   2475
# 2          3     33   6820
# 3          4     18   2141
# 4          5     67   7381
# ...      ...    ...    ...
# 49995  49996     41   3102
# 49996  49997     33   3906
# 49997  49998     41   2543
# 49998  49999     22   4651
# 49999  50000     22   2131
#
# [50000 rows x 3 columns]

# %%
df.select_dtypes(include = [int, object])
# Out:
#           Id  Idade  Renda       Sexo        Escolaridade
# 0          1     27   2554   Feminino  Ensino Fundamental
# 1          2     54   2475   Feminino     Ensino Superior
# 2          3     33   6820  Masculino     Ensino Superior
# 3          4     18   2141  Masculino        Ensino Médio
# 4          5     67   7381  Masculino  Ensino Fundamental
# ...      ...    ...    ...        ...                 ...
# 49995  49996     41   3102   Feminino     Ensino Superior
# 49996  49997     33   3906   Feminino     Ensino Superior
# 49997  49998     41   2543  Masculino     Ensino Superior
# 49998  49999     22   4651   Feminino     Ensino Superior
# 49999  50000     22   2131   Feminino     Ensino Superior
#
# [50000 rows x 5 columns]

# %%
df.select_dtypes(exclude = [object])
# Out:
#           Id  Idade  Renda  renda_média    ativo  renda_total
# 0          1     27   2554     3622.265  4690.53      7244.53
# 1          2     54   2475     2504.530  2534.06      5009.06
# 2          3     33   6820     4926.410  3032.82      9852.82
# 3          4     18   2141     2774.260  3407.52      5548.52
# 4          5     67   7381     4796.040  2211.08      9592.08
# ...      ...    ...    ...          ...      ...          ...
# 49995  49996     41   3102     2232.080  1362.16      4464.16
# 49996  49997     33   3906     3629.200  3352.40      7258.40
# 49997  49998     41   2543     2894.955  3246.91      5789.91
# 49998  49999     22   4651     3972.110  3293.22      7944.22
# 49999  50000     22   2131     2583.720  3036.44      5167.44
#
# [50000 rows x 6 columns]

# %%
df_transformed = df.copy()

# %% [markdown]
# astype(): cast a pandas object to a specified dtype ``dtype``

# %%
categorical_cols = df.select_dtypes(object).columns

# %%
categorical_cols
# Out:
# Index(['Sexo', 'Escolaridade'], dtype='object')

# %%
df_transformed.Sexo.astype('category')
# Out:
# 0         Feminino
# 1         Feminino
# 2        Masculino
# 3        Masculino
# 4        Masculino
#            ...
# 49995     Feminino
# 49996     Feminino
# 49997    Masculino
# 49998     Feminino
# 49999     Feminino
# Name: Sexo, Length: 50000, dtype: category
# Categories (2, object): [Feminino, Masculino]

# %%
df_transformed.Renda.astype(float)
# Out:
# 0        2554.0
# 1        2475.0
# 2        6820.0
# 3        2141.0
# 4        7381.0
#           ...
# 49995    3102.0
# 49996    3906.0
# 49997    2543.0
# 49998    4651.0
# 49999    2131.0
# Name: Renda, Length: 50000, dtype: float64

# %%
df_transformed.Renda = df_transformed.Renda.astype(float)

# %%
df_transformed.dtypes
# Out:
# Id                int64
# Idade             int64
# Renda           float64
# Sexo             object
# Escolaridade     object
# renda_média     float64
# ativo           float64
# renda_total     float64
# dtype: object

# %%
categorical_cols
# Out:
# Index(['Sexo', 'Escolaridade'], dtype='object')

# %%
# itera nas colunas do tipo object e converte para category
for categorical_col in categorical_cols:
    df_transformed[categorical_col] = df_transformed[categorical_col].astype('category')

# %%
df_transformed.dtypes
# Out:
# Id                 int64
# Idade              int64
# Renda            float64
# Sexo            category
# Escolaridade    category
# renda_média      float64
# ativo            float64
# renda_total      float64
# dtype: object

# %% [markdown]
# add_prefix() e add_suffix()

# %% [markdown]
# add_prefix(): For Series, the row labels are prefixed. For DataFrame, the column labels are prefixed.

# %%
df.add_prefix('cols_').head()
# Out:
#    cols_Id  cols_Idade  cols_Renda  cols_Sexo   cols_Escolaridade  \
# 0        1          27        2554   Feminino  Ensino Fundamental
# 1        2          54        2475   Feminino     Ensino Superior
# 2        3          33        6820  Masculino     Ensino Superior
# 3        4          18        2141  Masculino        Ensino Médio
# 4        5          67        7381  Masculino  Ensino Fundamental
#
#    cols_renda_média  cols_ativo  cols_renda_total
# 0          3622.265     4690.53           7244.53
# 1          2504.530     2534.06           5009.06
# 2          4926.410     3032.82           9852.82
# 3          2774.260     3407.52           5548.52
# 4          4796.040     2211.08           9592.08

# %%
df.Renda.add_prefix('wage_value_')
# Out:
# wage_value_0        2554
# wage_value_1        2475
# wage_value_2        6820
# wage_value_3        2141
# wage_value_4        7381
#                     ...
# wage_value_49995    3102
# wage_value_49996    3906
# wage_value_49997    2543
# wage_value_49998    4651
# wage_value_49999    2131
# Name: Renda, Length: 50000, dtype: int64

# %% [markdown]
# add_suffix(): For Series, the row labels are suffixed. For DataFrame, the column labels are suffixed.

# %%
df.add_suffix('_cols').head()
# Out:
#    Id_cols  Idade_cols  Renda_cols  Sexo_cols   Escolaridade_cols  \
# 0        1          27        2554   Feminino  Ensino Fundamental
# 1        2          54        2475   Feminino     Ensino Superior
# 2        3          33        6820  Masculino     Ensino Superior
# 3        4          18        2141  Masculino        Ensino Médio
# 4        5          67        7381  Masculino  Ensino Fundamental
#
#    renda_média_cols  ativo_cols  renda_total_cols
# 0          3622.265     4690.53           7244.53
# 1          2504.530     2534.06           5009.06
# 2          4926.410     3032.82           9852.82
# 3          2774.260     3407.52           5548.52
# 4          4796.040     2211.08           9592.08

# %%
df.Renda.add_suffix('_wage')
# Out:
# 0_wage        2554
# 1_wage        2475
# 2_wage        6820
# 3_wage        2141
# 4_wage        7381
#               ...
# 49995_wage    3102
# 49996_wage    3906
# 49997_wage    2543
# 49998_wage    4651
# 49999_wage    2131
# Name: Renda, Length: 50000, dtype: int64

# %% [markdown]
# isna() e notna()

# %%
df.isna().sum()
# Out:
# Id              0
# Idade           0
# Renda           0
# Sexo            0
# Escolaridade    0
# renda_média     0
# ativo           0
# renda_total     0
# dtype: int64

# %%
df.notna().sum()
# Out:
# Id              50000
# Idade           50000
# Renda           50000
# Sexo            50000
# Escolaridade    50000
# renda_média     50000
# ativo           50000
# renda_total     50000
# dtype: int64

# %%
# missing values por colunas
df.isna().sum()

# %%
df[df.notna()]
# Out:
#           Id  Idade  Renda       Sexo        Escolaridade  renda_média  \
# 0          1     27   2554   Feminino  Ensino Fundamental     3622.265
# 1          2     54   2475   Feminino     Ensino Superior     2504.530
# 2          3     33   6820  Masculino     Ensino Superior     4926.410
# 3          4     18   2141  Masculino        Ensino Médio     2774.260
# 4          5     67   7381  Masculino  Ensino Fundamental     4796.040
# ...      ...    ...    ...        ...                 ...          ...
# 49995  49996     41   3102   Feminino     Ensino Superior     2232.080
# 49996  49997     33   3906   Feminino     Ensino Superior     3629.200
# 49997  49998     41   2543  Masculino     Ensino Superior     2894.955
# 49998  49999     22   4651   Feminino     Ensino Superior     3972.110
# 49999  50000     22   2131   Feminino     Ensino Superior     2583.720
#
#          ativo  renda_total
# 0      4690.53      7244.53
# 1      2534.06      5009.06
# 2      3032.82      9852.82
# 3      3407.52      5548.52
# 4      2211.08      9592.08
# ...        ...          ...
# 49995  1362.16      4464.16
# 49996  3352.40      7258.40
# 49997  3246.91      5789.91
# 49998  3293.22      7944.22
# 49999  3036.44      5167.44
#
# [50000 rows x 8 columns]

# %%
# drop de missing values
# veremos mais adiante uma aplicação desta função, que possui vários parâmetros
df.dropna().head()
# Out:
#    Id  Idade  Renda       Sexo        Escolaridade  renda_média    ativo  \
# 0   1     27   2554   Feminino  Ensino Fundamental     3622.265  4690.53
# 1   2     54   2475   Feminino     Ensino Superior     2504.530  2534.06
# 2   3     33   6820  Masculino     Ensino Superior     4926.410  3032.82
# 3   4     18   2141  Masculino        Ensino Médio     2774.260  3407.52
# 4   5     67   7381  Masculino  Ensino Fundamental     4796.040  2211.08
#
#    renda_total
# 0      7244.53
# 1      5009.06
# 2      9852.82
# 3      5548.52
# 4      9592.08

# %%
# verifica se uma linha é duplicada
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 49995    False
# 49996    False
# 49997    False
# 49998    False
# 49999    False
# Length: 50000, dtype: bool

# %%
# soma das linhas duplicadas
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (50000, 8)

# %%
# valos únicos
df.Sexo.unique().tolist()
# Out:
# ['Feminino', 'Masculino']

# %%
# conta os valores únicos
df.Sexo.nunique()
# Out:
# 2

# %%
# conta os valores únicos em cada coluna
df.nunique()
# Out:
# Id              50000
# Idade              52
# Renda            8475
# Sexo                2
# Escolaridade        3
# renda_média     48777
# ativo           46653
# renda_total     48777
# dtype: int64

# %%
df.Sexo.head(10)
# Out:
# 0     Feminino
# 1     Feminino
# 2    Masculino
# 3    Masculino
# 4    Masculino
# 5    Masculino
# 6    Masculino
# 7    Masculino
# 8     Feminino
# 9    Masculino
# Name: Sexo, dtype: object

# %%
df.Sexo.replace({
    'Feminino': 'F',
    'Masculino': 'M'
})
# Out:
# 0        F
# 1        F
# 2        M
# 3        M
# 4        M
#         ..
# 49995    F
# 49996    F
# 49997    M
# 49998    F
# 49999    F
# Name: Sexo, Length: 50000, dtype: object

# %%
# altera a configuração dos valores da coluna Sexo
df['Sexo modificado'] = df.Sexo.replace({
    'Feminino': 'F',
    'Masculino': 'M'
})

# %%
df
# Out:
#           Id  Idade  Renda       Sexo        Escolaridade  renda_média  \
# 0          1     27   2554   Feminino  Ensino Fundamental     3622.265
# 1          2     54   2475   Feminino     Ensino Superior     2504.530
# 2          3     33   6820  Masculino     Ensino Superior     4926.410
# 3          4     18   2141  Masculino        Ensino Médio     2774.260
# 4          5     67   7381  Masculino  Ensino Fundamental     4796.040
# ...      ...    ...    ...        ...                 ...          ...
# 49995  49996     41   3102   Feminino     Ensino Superior     2232.080
# 49996  49997     33   3906   Feminino     Ensino Superior     3629.200
# 49997  49998     41   2543  Masculino     Ensino Superior     2894.955
# 49998  49999     22   4651   Feminino     Ensino Superior     3972.110
# 49999  50000     22   2131   Feminino     Ensino Superior     2583.720
#
#          ativo  renda_total Sexo modificado
# 0      4690.53      7244.53               F
# 1      2534.06      5009.06               F
# 2      3032.82      9852.82               M
# 3      3407.52      5548.52               M
# 4      2211.08      9592.08               M
# ...        ...          ...             ...
# 49995  1362.16      4464.16               F
# 49996  3352.40      7258.40               F
# 49997  3246.91      5789.91               M
# 49998  3293.22      7944.22               F
# 49999  3036.44      5167.44               F
#
# [50000 rows x 9 columns]

# %%
# poderíamos usar para criar uma coluna dummy
df.Sexo.replace({
    'Masculino': 0,
    'Feminino': 1
})
# Out:
# 0        1
# 1        1
# 2        0
# 3        0
# 4        0
#         ..
# 49995    1
# 49996    1
# 49997    0
# 49998    1
# 49999    1
# Name: Sexo, Length: 50000, dtype: int64

# %% [markdown]
# O Pandas possui uma função específica para criar variáveis dummies. Antes de aplicar algum modelo estatístico ou de Machine Learning precisamos transformar as variáveis categóricas em número.

# %%
pd.get_dummies(df.Sexo)
# Out:
#        Feminino  Masculino
# 0             1          0
# 1             1          0
# 2             0          1
# 3             0          1
# 4             0          1
# ...         ...        ...
# 49995         1          0
# 49996         1          0
# 49997         0          1
# 49998         1          0
# 49999         1          0
#
# [50000 rows x 2 columns]

# %%
pd.get_dummies(df.Sexo, drop_first = True, prefix = 'sexo')
# Out:
#        sexo_Masculino
# 0                   0
# 1                   0
# 2                   1
# 3                   1
# 4                   1
# ...               ...
# 49995               0
# 49996               0
# 49997               1
# 49998               0
# 49999               0
#
# [50000 rows x 1 columns]

# %%
# podemos fazer dummies para todas as colunas categóricas de uma única vez
pd.get_dummies(df, drop_first = True)
# Out:
#           Id  Idade  Renda  renda_média    ativo  renda_total  Sexo_Masculino  \
# 0          1     27   2554     3622.265  4690.53      7244.53               0
# 1          2     54   2475     2504.530  2534.06      5009.06               0
# 2          3     33   6820     4926.410  3032.82      9852.82               1
# 3          4     18   2141     2774.260  3407.52      5548.52               1
# 4          5     67   7381     4796.040  2211.08      9592.08               1
# ...      ...    ...    ...          ...      ...          ...             ...
# 49995  49996     41   3102     2232.080  1362.16      4464.16               0
# 49996  49997     33   3906     3629.200  3352.40      7258.40               0
# 49997  49998     41   2543     2894.955  3246.91      5789.91               1
# 49998  49999     22   4651     3972.110  3293.22      7944.22               0
# 49999  50000     22   2131     2583.720  3036.44      5167.44               0
#
#        Escolaridade_Ensino Médio  Escolaridade_Ensino Superior  \
# 0                              0                             0
# 1                              0                             1
# 2                              0                             1
# 3                              1                             0
# 4                              0                             0
# ...                          ...                           ...
# 49995                          0                             1
# 49996                          0                             1
# 49997                          0                             1
# 49998                          0                             1
# 49999                          0                             1
#
#        Sexo modificado_M
# 0                      0
# 1                      0
# 2                      1
# 3                      1
# 4                      1
# ...                  ...
# 49995                  0
# 49996                  0
# 49997                  1
# 49998                  0
# 49999                  0
#
# [50000 rows x 10 columns]

# %% [markdown]
# Vejamos agora algumas opções para tratar strings:

# %%
df.Sexo.str.

# %%
df['Sexo modificado'].str.replace('F', 'Feminino')
# Out:
# 0        Feminino
# 1        Feminino
# 2               M
# 3               M
# 4               M
#            ...
# 49995    Feminino
# 49996    Feminino
# 49997           M
# 49998    Feminino
# 49999    Feminino
# Name: Sexo modificado, Length: 50000, dtype: object

# %%
df['Sexo'].str.lower()
# Out:
# 0         feminino
# 1         feminino
# 2        masculino
# 3        masculino
# 4        masculino
#            ...
# 49995     feminino
# 49996     feminino
# 49997    masculino
# 49998     feminino
# 49999     feminino
# Name: Sexo, Length: 50000, dtype: object

# %%
df['Sexo'].str.upper()
# Out:
# 0         FEMININO
# 1         FEMININO
# 2        MASCULINO
# 3        MASCULINO
# 4        MASCULINO
#            ...
# 49995     FEMININO
# 49996     FEMININO
# 49997    MASCULINO
# 49998     FEMININO
# 49999     FEMININO
# Name: Sexo, Length: 50000, dtype: object

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop_duplicates(keep = 'first').shape
# Out:
# (50000, 9)

# %%
df.shape
# Out:
# (50000, 9)
