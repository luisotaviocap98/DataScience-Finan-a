# %%
import pandas as pd
import numpy as np

# %%
np.random.seed(10)
n = 50_000

escolaridade = ['Ensino Fundamental', 'Ensino Médio', 'Ensino Superior']

data = {
    'Id': np.arange(1, n+1),
    'Idade': np.random.randint(18, 70, size = n),
    'Renda': np.random.randint(1_500, 10_000, size = n),
    'Sexo': np.random.choice(['Masculino', 'Feminino'], size = n),
    'Escolaridade': np.random.choice(escolaridade, size = n)
}

df = pd.DataFrame(data)

# %%
np.random.seed(7)
ativos = pd.Series(np.random.normal(3_000, 1000, size = n)).round(2)

# %%
# cria coluna de ativos
df['ativo'] = ativos

# %%
# cria coluna de renda total
df['renda_total'] = df['Renda']+df['ativo']

# %%
# renda média (ativos e renda)
renda_media = df.loc[:, ['Renda', 'ativo']].mean(axis = 1)

# %%
# posição da coluna 'ativo'
posicao = df.columns.to_list().index('ativo')

# %%
# insere a coluna renda_media na posição da coluna 'ativo'
df.insert(posicao, 'renda_média', renda_media )

# %%
df
# Out:
#           Id  Idade  Renda       Sexo        Escolaridade  renda_média  \
# 0          1     27   2554   Feminino  Ensino Fundamental     3622.265
# 1          2     54   2475   Feminino     Ensino Superior     2504.530
# 2          3     33   6820  Masculino     Ensino Superior     4926.410
# 3          4     18   2141  Masculino        Ensino Médio     2774.260
# 4          5     67   7381  Masculino  Ensino Fundamental     4796.040
# ...      ...    ...    ...        ...                 ...          ...
# 49995  49996     41   3102   Feminino     Ensino Superior     2232.080
# 49996  49997     33   3906   Feminino     Ensino Superior     3629.200
# 49997  49998     41   2543  Masculino     Ensino Superior     2894.955
# 49998  49999     22   4651   Feminino     Ensino Superior     3972.110
# 49999  50000     22   2131   Feminino     Ensino Superior     2583.720
#
#          ativo  renda_total
# 0      4690.53      7244.53
# 1      2534.06      5009.06
# 2      3032.82      9852.82
# 3      3407.52      5548.52
# 4      2211.08      9592.08
# ...        ...          ...
# 49995  1362.16      4464.16
# 49996  3352.40      7258.40
# 49997  3246.91      5789.91
# 49998  3293.22      7944.22
# 49999  3036.44      5167.44
#
# [50000 rows x 8 columns]

# %% [markdown]
# ## Consultas
# Nesta seção aprenderemos a fazer filtro com os dados. Por exemplo, como filtrar os dados a partir de uma determinada categoria ou de um conjunto de condições?

# %%
df.head()
# Out:
#    Id  Idade  Renda       Sexo        Escolaridade  renda_média    ativo  \
# 0   1     27   2554   Feminino  Ensino Fundamental     3622.265  4690.53
# 1   2     54   2475   Feminino     Ensino Superior     2504.530  2534.06
# 2   3     33   6820  Masculino     Ensino Superior     4926.410  3032.82
# 3   4     18   2141  Masculino        Ensino Médio     2774.260  3407.52
# 4   5     67   7381  Masculino  Ensino Fundamental     4796.040  2211.08
#
#    renda_total
# 0      7244.53
# 1      5009.06
# 2      9852.82
# 3      5548.52
# 4      9592.08

# %%
# condição simples: filtra os dados a partir do sexo Feminino
df[df.Sexo == 'Feminino']['Sexo'].unique()
# Out:
# array(['Feminino'], dtype=object)

# %%
df.query('Sexo == "Feminino"')
# Out:
#           Id  Idade  Renda      Sexo        Escolaridade  renda_média  \
# 0          1     27   2554  Feminino  Ensino Fundamental     3622.265
# 1          2     54   2475  Feminino     Ensino Superior     2504.530
# 8          9     66   3783  Feminino     Ensino Superior     3900.330
# 10        11     67   6173  Feminino        Ensino Médio     4273.785
# 11        12     26   4193  Feminino  Ensino Fundamental     3510.725
# ...      ...    ...    ...       ...                 ...          ...
# 49994  49995     28   2951  Feminino     Ensino Superior     3007.900
# 49995  49996     41   3102  Feminino     Ensino Superior     2232.080
# 49996  49997     33   3906  Feminino     Ensino Superior     3629.200
# 49998  49999     22   4651  Feminino     Ensino Superior     3972.110
# 49999  50000     22   2131  Feminino     Ensino Superior     2583.720
#
#          ativo  renda_total
# 0      4690.53      7244.53
# 1      2534.06      5009.06
# 8      4017.66      7800.66
# 10     2374.57      8547.57
# 11     2828.45      7021.45
# ...        ...          ...
# 49994  3064.80      6015.80
# 49995  1362.16      4464.16
# 49996  3352.40      7258.40
# 49998  3293.22      7944.22
# 49999  3036.44      5167.44
#
# [24980 rows x 8 columns]

# %%
df.query("Sexo == "Feminino"")
# Out:
#   File "<ipython-input-19-e0dd025f9db6>", line 1
#     df.query("Sexo == "Feminino"")
#                        ^
# SyntaxError: invalid syntax

# %%
df.loc[df.Sexo == 'Feminino']['Sexo'].unique()
# Out:
# array(['Feminino'], dtype=object)

# %%
# condição 1: sexo feminino
# condição 2: escolaridade ensino superior
# AND: &

# %%
df[(df.Sexo == 'Feminino') & (df.Escolaridade == 'Ensino Superior')]
# Out:
#           Id  Idade  Renda      Sexo     Escolaridade  renda_média    ativo  \
# 1          2     54   2475  Feminino  Ensino Superior     2504.530  2534.06
# 8          9     66   3783  Feminino  Ensino Superior     3900.330  4017.66
# 14        15     60   1982  Feminino  Ensino Superior     2369.625  2757.25
# 34        35     43   9198  Feminino  Ensino Superior     5066.795   935.59
# 35        36     31   3014  Feminino  Ensino Superior     2675.920  2337.84
# ...      ...    ...    ...       ...              ...          ...      ...
# 49994  49995     28   2951  Feminino  Ensino Superior     3007.900  3064.80
# 49995  49996     41   3102  Feminino  Ensino Superior     2232.080  1362.16
# 49996  49997     33   3906  Feminino  Ensino Superior     3629.200  3352.40
# 49998  49999     22   4651  Feminino  Ensino Superior     3972.110  3293.22
# 49999  50000     22   2131  Feminino  Ensino Superior     2583.720  3036.44
#
#        renda_total
# 1          5009.06
# 8          7800.66
# 14         4739.25
# 34        10133.59
# 35         5351.84
# ...            ...
# 49994      6015.80
# 49995      4464.16
# 49996      7258.40
# 49998      7944.22
# 49999      5167.44
#
# [8358 rows x 8 columns]

# %%
df.query("(Sexo == 'Feminino') & (Escolaridade == 'Ensino Superior')")[['Sexo', 'Escolaridade']].nunique()
# Out:
# Sexo            1
# Escolaridade    1
# dtype: int64

# %%
df.loc[(df.Sexo == 'Feminino') & (df.Escolaridade == 'Ensino Superior')]
# Out:
#           Id  Idade  Renda      Sexo     Escolaridade  renda_média    ativo  \
# 1          2     54   2475  Feminino  Ensino Superior     2504.530  2534.06
# 8          9     66   3783  Feminino  Ensino Superior     3900.330  4017.66
# 14        15     60   1982  Feminino  Ensino Superior     2369.625  2757.25
# 34        35     43   9198  Feminino  Ensino Superior     5066.795   935.59
# 35        36     31   3014  Feminino  Ensino Superior     2675.920  2337.84
# ...      ...    ...    ...       ...              ...          ...      ...
# 49994  49995     28   2951  Feminino  Ensino Superior     3007.900  3064.80
# 49995  49996     41   3102  Feminino  Ensino Superior     2232.080  1362.16
# 49996  49997     33   3906  Feminino  Ensino Superior     3629.200  3352.40
# 49998  49999     22   4651  Feminino  Ensino Superior     3972.110  3293.22
# 49999  50000     22   2131  Feminino  Ensino Superior     2583.720  3036.44
#
#        renda_total
# 1          5009.06
# 8          7800.66
# 14         4739.25
# 34        10133.59
# 35         5351.84
# ...            ...
# 49994      6015.80
# 49995      4464.16
# 49996      7258.40
# 49998      7944.22
# 49999      5167.44
#
# [8358 rows x 8 columns]

# %%
# condição 1: sexo masculino
# condição 2: renda>= 7_500 (==, !=, >, <, >=, <=)

# %%
df[(df.Sexo == 'Masculino') & (df.Renda >= 7_500)]
# Out:
#           Id  Idade  Renda       Sexo        Escolaridade  renda_média  \
# 6          7     43   9235  Masculino     Ensino Superior     6117.055
# 15        16     58   8781  Masculino  Ensino Fundamental     5163.880
# 25        26     26   9334  Masculino     Ensino Superior     5441.660
# 30        31     31   7724  Masculino     Ensino Superior     4990.725
# 32        33     31   7598  Masculino        Ensino Médio     4473.460
# ...      ...    ...    ...        ...                 ...          ...
# 49979  49980     59   9848  Masculino     Ensino Superior     6033.375
# 49980  49981     40   7850  Masculino        Ensino Médio     4891.430
# 49981  49982     38   7913  Masculino     Ensino Superior     6185.480
# 49984  49985     57   8763  Masculino        Ensino Médio     5136.355
# 49990  49991     47   9160  Masculino  Ensino Fundamental     6185.390
#
#          ativo  renda_total
# 6      2999.11     12234.11
# 15     1546.76     10327.76
# 25     1549.32     10883.32
# 30     2257.45      9981.45
# 32     1348.92      8946.92
# ...        ...          ...
# 49979  2218.75     12066.75
# 49980  1932.86      9782.86
# 49981  4457.96     12370.96
# 49984  1509.71     10272.71
# 49990  3210.78     12370.78
#
# [7241 rows x 8 columns]

# %%
df.loc[(df.Sexo == 'Masculino') & (df.Renda >= 7_500)]
# Out:
#           Id  Idade  Renda       Sexo        Escolaridade  renda_média  \
# 6          7     43   9235  Masculino     Ensino Superior     6117.055
# 15        16     58   8781  Masculino  Ensino Fundamental     5163.880
# 25        26     26   9334  Masculino     Ensino Superior     5441.660
# 30        31     31   7724  Masculino     Ensino Superior     4990.725
# 32        33     31   7598  Masculino        Ensino Médio     4473.460
# ...      ...    ...    ...        ...                 ...          ...
# 49979  49980     59   9848  Masculino     Ensino Superior     6033.375
# 49980  49981     40   7850  Masculino        Ensino Médio     4891.430
# 49981  49982     38   7913  Masculino     Ensino Superior     6185.480
# 49984  49985     57   8763  Masculino        Ensino Médio     5136.355
# 49990  49991     47   9160  Masculino  Ensino Fundamental     6185.390
#
#          ativo  renda_total
# 6      2999.11     12234.11
# 15     1546.76     10327.76
# 25     1549.32     10883.32
# 30     2257.45      9981.45
# 32     1348.92      8946.92
# ...        ...          ...
# 49979  2218.75     12066.75
# 49980  1932.86      9782.86
# 49981  4457.96     12370.96
# 49984  1509.71     10272.71
# 49990  3210.78     12370.78
#
# [7241 rows x 8 columns]

# %%
df.query('(Sexo == "Masculino") & (Renda>=7_500)')
# Out:
#           Id  Idade  Renda       Sexo        Escolaridade  renda_média  \
# 6          7     43   9235  Masculino     Ensino Superior     6117.055
# 15        16     58   8781  Masculino  Ensino Fundamental     5163.880
# 25        26     26   9334  Masculino     Ensino Superior     5441.660
# 30        31     31   7724  Masculino     Ensino Superior     4990.725
# 32        33     31   7598  Masculino        Ensino Médio     4473.460
# ...      ...    ...    ...        ...                 ...          ...
# 49979  49980     59   9848  Masculino     Ensino Superior     6033.375
# 49980  49981     40   7850  Masculino        Ensino Médio     4891.430
# 49981  49982     38   7913  Masculino     Ensino Superior     6185.480
# 49984  49985     57   8763  Masculino        Ensino Médio     5136.355
# 49990  49991     47   9160  Masculino  Ensino Fundamental     6185.390
#
#          ativo  renda_total
# 6      2999.11     12234.11
# 15     1546.76     10327.76
# 25     1549.32     10883.32
# 30     2257.45      9981.45
# 32     1348.92      8946.92
# ...        ...          ...
# 49979  2218.75     12066.75
# 49980  1932.86      9782.86
# 49981  4457.96     12370.96
# 49984  1509.71     10272.71
# 49990  3210.78     12370.78
#
# [7241 rows x 8 columns]

# %%
# condição 1: escolaridade Ensino Fundamental
# condição 2: escolaridade Ensino Médio
# OR: |

# %%
df[(df.Escolaridade == 'Ensino Fundamental') | (df.Escolaridade == 'Ensino Médio')]
# Out:
#           Id  Idade  Renda       Sexo        Escolaridade  renda_média  \
# 0          1     27   2554   Feminino  Ensino Fundamental     3622.265
# 3          4     18   2141  Masculino        Ensino Médio     2774.260
# 4          5     67   7381  Masculino  Ensino Fundamental     4796.040
# 5          6     46   4113  Masculino  Ensino Fundamental     3557.535
# 7          8     47   2336  Masculino        Ensino Médio     1790.640
# ...      ...    ...    ...        ...                 ...          ...
# 49987  49988     41   3830  Masculino  Ensino Fundamental     4250.265
# 49988  49989     46   2877   Feminino        Ensino Médio     3227.805
# 49990  49991     47   9160  Masculino  Ensino Fundamental     6185.390
# 49991  49992     67   2406  Masculino  Ensino Fundamental     2520.275
# 49993  49994     43   6189  Masculino        Ensino Médio     4582.920
#
#          ativo  renda_total
# 0      4690.53      7244.53
# 3      3407.52      5548.52
# 4      2211.08      9592.08
# 5      3002.07      7115.07
# 7      1245.28      3581.28
# ...        ...          ...
# 49987  4670.53      8500.53
# 49988  3578.61      6455.61
# 49990  3210.78     12370.78
# 49991  2634.55      5040.55
# 49993  2976.84      9165.84
#
# [33322 rows x 8 columns]

# %%
df.query('(Escolaridade == "Ensino Fundamental") | (Escolaridade == "Ensino Médio")')
# Out:
#           Id  Idade  Renda       Sexo        Escolaridade  renda_média  \
# 0          1     27   2554   Feminino  Ensino Fundamental     3622.265
# 3          4     18   2141  Masculino        Ensino Médio     2774.260
# 4          5     67   7381  Masculino  Ensino Fundamental     4796.040
# 5          6     46   4113  Masculino  Ensino Fundamental     3557.535
# 7          8     47   2336  Masculino        Ensino Médio     1790.640
# ...      ...    ...    ...        ...                 ...          ...
# 49987  49988     41   3830  Masculino  Ensino Fundamental     4250.265
# 49988  49989     46   2877   Feminino        Ensino Médio     3227.805
# 49990  49991     47   9160  Masculino  Ensino Fundamental     6185.390
# 49991  49992     67   2406  Masculino  Ensino Fundamental     2520.275
# 49993  49994     43   6189  Masculino        Ensino Médio     4582.920
#
#          ativo  renda_total
# 0      4690.53      7244.53
# 3      3407.52      5548.52
# 4      2211.08      9592.08
# 5      3002.07      7115.07
# 7      1245.28      3581.28
# ...        ...          ...
# 49987  4670.53      8500.53
# 49988  3578.61      6455.61
# 49990  3210.78     12370.78
# 49991  2634.55      5040.55
# 49993  2976.84      9165.84
#
# [33322 rows x 8 columns]

# %%
df.loc[(df.Escolaridade == 'Ensino Fundamental') | (df.Escolaridade == 'Ensino Médio')]
# Out:
#           Id  Idade  Renda       Sexo        Escolaridade  renda_média  \
# 0          1     27   2554   Feminino  Ensino Fundamental     3622.265
# 3          4     18   2141  Masculino        Ensino Médio     2774.260
# 4          5     67   7381  Masculino  Ensino Fundamental     4796.040
# 5          6     46   4113  Masculino  Ensino Fundamental     3557.535
# 7          8     47   2336  Masculino        Ensino Médio     1790.640
# ...      ...    ...    ...        ...                 ...          ...
# 49987  49988     41   3830  Masculino  Ensino Fundamental     4250.265
# 49988  49989     46   2877   Feminino        Ensino Médio     3227.805
# 49990  49991     47   9160  Masculino  Ensino Fundamental     6185.390
# 49991  49992     67   2406  Masculino  Ensino Fundamental     2520.275
# 49993  49994     43   6189  Masculino        Ensino Médio     4582.920
#
#          ativo  renda_total
# 0      4690.53      7244.53
# 3      3407.52      5548.52
# 4      2211.08      9592.08
# 5      3002.07      7115.07
# 7      1245.28      3581.28
# ...        ...          ...
# 49987  4670.53      8500.53
# 49988  3578.61      6455.61
# 49990  3210.78     12370.78
# 49991  2634.55      5040.55
# 49993  2976.84      9165.84
#
# [33322 rows x 8 columns]

# %%
df.loc[df.Escolaridade != 'Ensino Superior']
# Out:
#           Id  Idade  Renda       Sexo        Escolaridade  renda_média  \
# 0          1     27   2554   Feminino  Ensino Fundamental     3622.265
# 3          4     18   2141  Masculino        Ensino Médio     2774.260
# 4          5     67   7381  Masculino  Ensino Fundamental     4796.040
# 5          6     46   4113  Masculino  Ensino Fundamental     3557.535
# 7          8     47   2336  Masculino        Ensino Médio     1790.640
# ...      ...    ...    ...        ...                 ...          ...
# 49987  49988     41   3830  Masculino  Ensino Fundamental     4250.265
# 49988  49989     46   2877   Feminino        Ensino Médio     3227.805
# 49990  49991     47   9160  Masculino  Ensino Fundamental     6185.390
# 49991  49992     67   2406  Masculino  Ensino Fundamental     2520.275
# 49993  49994     43   6189  Masculino        Ensino Médio     4582.920
#
#          ativo  renda_total
# 0      4690.53      7244.53
# 3      3407.52      5548.52
# 4      2211.08      9592.08
# 5      3002.07      7115.07
# 7      1245.28      3581.28
# ...        ...          ...
# 49987  4670.53      8500.53
# 49988  3578.61      6455.61
# 49990  3210.78     12370.78
# 49991  2634.55      5040.55
# 49993  2976.84      9165.84
#
# [33322 rows x 8 columns]

# %%
# condição 1: renda>=8_000
# condição 2: idade>=50
# condição 3: feminino

df[(df.Renda >= 8_000) & (df.Idade >= 50) & (df.Sexo == 'Feminino')]\
.sort_values(by = ['Idade', 'Renda'])\
.reset_index(drop = True)\
.drop(columns = ['Id'])[['Renda', 'Idade']]\
.query('Idade >= 60')
# Out:
#       Renda  Idade
# 1121   8014     60
# 1122   8020     60
# 1123   8042     60
# 1124   8092     60
# 1125   8133     60
# ...     ...    ...
# 2245   9845     69
# 2246   9933     69
# 2247   9961     69
# 2248   9970     69
# 2249   9975     69
#
# [1129 rows x 2 columns]

# %%
(
    df[(df.Renda >= 8_000) & (df.Idade >= 50) & (df.Sexo == 'Feminino')]
.sort_values(by = ['Idade', 'Renda'])
.reset_index(drop = True)
.drop(columns = ['Id'])[['Renda', 'Idade']]
.query('Idade >= 60')
)
# Out:
#       Renda  Idade
# 1121   8014     60
# 1122   8020     60
# 1123   8042     60
# 1124   8092     60
# 1125   8133     60
# ...     ...    ...
# 2245   9845     69
# 2246   9933     69
# 2247   9961     69
# 2248   9970     69
# 2249   9975     69
#
# [1129 rows x 2 columns]

# %%
df.query('(Renda >= 8_000) & (Idade >= 50) & (Sexo == "Feminino")')
# Out:
#           Id  Idade  Renda      Sexo        Escolaridade  renda_média  \
# 24        25     51   8772  Feminino  Ensino Fundamental     5863.305
# 78        79     68   9295  Feminino        Ensino Médio     6051.070
# 148      149     50   9215  Feminino  Ensino Fundamental     5966.945
# 156      157     61   9303  Feminino  Ensino Fundamental     5373.355
# 161      162     67   9307  Feminino  Ensino Fundamental     6359.400
# ...      ...    ...    ...       ...                 ...          ...
# 49808  49809     60   9891  Feminino  Ensino Fundamental     6267.410
# 49844  49845     55   9176  Feminino        Ensino Médio     5971.850
# 49854  49855     61   9566  Feminino     Ensino Superior     5666.755
# 49886  49887     58   8013  Feminino     Ensino Superior     5047.010
# 49919  49920     61   9119  Feminino  Ensino Fundamental     6124.495
#
#          ativo  renda_total
# 24     2954.61     11726.61
# 78     2807.14     12102.14
# 148    2718.89     11933.89
# 156    1443.71     10746.71
# 161    3411.80     12718.80
# ...        ...          ...
# 49808  2643.82     12534.82
# 49844  2767.70     11943.70
# 49854  1767.51     11333.51
# 49886  2081.02     10094.02
# 49919  3129.99     12248.99
#
# [2250 rows x 8 columns]

# %%
df.loc[(df.Renda>=8_000) & (df.Idade>=50) & (df.Sexo == 'Feminino')]
# Out:
#           Id  Idade  Renda      Sexo        Escolaridade  renda_média  \
# 24        25     51   8772  Feminino  Ensino Fundamental     5863.305
# 78        79     68   9295  Feminino        Ensino Médio     6051.070
# 148      149     50   9215  Feminino  Ensino Fundamental     5966.945
# 156      157     61   9303  Feminino  Ensino Fundamental     5373.355
# 161      162     67   9307  Feminino  Ensino Fundamental     6359.400
# ...      ...    ...    ...       ...                 ...          ...
# 49808  49809     60   9891  Feminino  Ensino Fundamental     6267.410
# 49844  49845     55   9176  Feminino        Ensino Médio     5971.850
# 49854  49855     61   9566  Feminino     Ensino Superior     5666.755
# 49886  49887     58   8013  Feminino     Ensino Superior     5047.010
# 49919  49920     61   9119  Feminino  Ensino Fundamental     6124.495
#
#          ativo  renda_total
# 24     2954.61     11726.61
# 78     2807.14     12102.14
# 148    2718.89     11933.89
# 156    1443.71     10746.71
# 161    3411.80     12718.80
# ...        ...          ...
# 49808  2643.82     12534.82
# 49844  2767.70     11943.70
# 49854  1767.51     11333.51
# 49886  2081.02     10094.02
# 49919  3129.99     12248.99
#
# [2250 rows x 8 columns]

# %%
df.rename(columns = {'renda_média': 'renda média'}, inplace = True)

# %%
df.rename(columns = {'renda_total': 'renda total'}, inplace = True)

# %%
df.query('`renda média` >= 7000')
# Out:
#           Id  Idade  Renda       Sexo        Escolaridade  renda média  \
# 88        89     60   9822  Masculino        Ensino Médio     7175.790
# 189      190     35   9995  Masculino  Ensino Fundamental     7066.490
# 312      313     66   9911  Masculino        Ensino Médio     7128.645
# 348      349     40   9738  Masculino        Ensino Médio     7198.780
# 564      565     43   8886   Feminino     Ensino Superior     7198.405
# ...      ...    ...    ...        ...                 ...          ...
# 49524  49525     58   9700  Masculino     Ensino Superior     7009.535
# 49556  49557     45   8464  Masculino  Ensino Fundamental     7338.420
# 49585  49586     65   9874  Masculino        Ensino Médio     7006.835
# 49710  49711     32   9137   Feminino        Ensino Médio     7035.160
# 49751  49752     56   9821  Masculino     Ensino Superior     7025.390
#
#          ativo  renda total
# 88     4529.58     14351.58
# 189    4137.98     14132.98
# 312    4346.29     14257.29
# 348    4659.56     14397.56
# 564    5510.81     14396.81
# ...        ...          ...
# 49524  4319.07     14019.07
# 49556  6212.84     14676.84
# 49585  4139.67     14013.67
# 49710  4933.32     14070.32
# 49751  4229.78     14050.78
#
# [437 rows x 8 columns]

# %%
df.query('(`renda média` >= 5_000) & (`renda total` >= 8_000)')
# Out:
#           Id  Idade  Renda       Sexo        Escolaridade  renda média  \
# 6          7     43   9235  Masculino     Ensino Superior     6117.055
# 15        16     58   8781  Masculino  Ensino Fundamental     5163.880
# 22        23     42   7966   Feminino  Ensino Fundamental     5289.430
# 24        25     51   8772   Feminino  Ensino Fundamental     5863.305
# 25        26     26   9334  Masculino     Ensino Superior     5441.660
# ...      ...    ...    ...        ...                 ...          ...
# 49981  49982     38   7913  Masculino     Ensino Superior     6185.480
# 49983  49984     45   9414   Feminino  Ensino Fundamental     5983.850
# 49984  49985     57   8763  Masculino        Ensino Médio     5136.355
# 49986  49987     42   7141  Masculino  Ensino Fundamental     5185.875
# 49990  49991     47   9160  Masculino  Ensino Fundamental     6185.390
#
#          ativo  renda total
# 6      2999.11     12234.11
# 15     1546.76     10327.76
# 22     2612.86     10578.86
# 24     2954.61     11726.61
# 25     1549.32     10883.32
# ...        ...          ...
# 49981  4457.96     12370.96
# 49983  2553.70     11967.70
# 49984  1509.71     10272.71
# 49986  3230.75     10371.75
# 49990  3210.78     12370.78
#
# [17637 rows x 8 columns]

# %%
~(df.Sexo == 'Feminino')
# Out:
# 0        False
# 1        False
# 2         True
# 3         True
# 4         True
#          ...
# 49995    False
# 49996    False
# 49997     True
# 49998    False
# 49999    False
# Name: Sexo, Length: 50000, dtype: bool

# %%
df.loc[~(df.Sexo == 'Feminino')]
# Out:
#           Id  Idade  Renda       Sexo        Escolaridade  renda média  \
# 2          3     33   6820  Masculino     Ensino Superior     4926.410
# 3          4     18   2141  Masculino        Ensino Médio     2774.260
# 4          5     67   7381  Masculino  Ensino Fundamental     4796.040
# 5          6     46   4113  Masculino  Ensino Fundamental     3557.535
# 6          7     43   9235  Masculino     Ensino Superior     6117.055
# ...      ...    ...    ...        ...                 ...          ...
# 49989  49990     69   5049  Masculino     Ensino Superior     2853.450
# 49990  49991     47   9160  Masculino  Ensino Fundamental     6185.390
# 49991  49992     67   2406  Masculino  Ensino Fundamental     2520.275
# 49993  49994     43   6189  Masculino        Ensino Médio     4582.920
# 49997  49998     41   2543  Masculino     Ensino Superior     2894.955
#
#          ativo  renda total
# 2      3032.82      9852.82
# 3      3407.52      5548.52
# 4      2211.08      9592.08
# 5      3002.07      7115.07
# 6      2999.11     12234.11
# ...        ...          ...
# 49989   657.90      5706.90
# 49990  3210.78     12370.78
# 49991  2634.55      5040.55
# 49993  2976.84      9165.84
# 49997  3246.91      5789.91
#
# [25020 rows x 8 columns]

# %%
df.loc[~(df.Escolaridade == 'Ensino Superior')]
# Out:
#           Id  Idade  Renda       Sexo        Escolaridade  renda média  \
# 0          1     27   2554   Feminino  Ensino Fundamental     3622.265
# 3          4     18   2141  Masculino        Ensino Médio     2774.260
# 4          5     67   7381  Masculino  Ensino Fundamental     4796.040
# 5          6     46   4113  Masculino  Ensino Fundamental     3557.535
# 7          8     47   2336  Masculino        Ensino Médio     1790.640
# ...      ...    ...    ...        ...                 ...          ...
# 49987  49988     41   3830  Masculino  Ensino Fundamental     4250.265
# 49988  49989     46   2877   Feminino        Ensino Médio     3227.805
# 49990  49991     47   9160  Masculino  Ensino Fundamental     6185.390
# 49991  49992     67   2406  Masculino  Ensino Fundamental     2520.275
# 49993  49994     43   6189  Masculino        Ensino Médio     4582.920
#
#          ativo  renda total
# 0      4690.53      7244.53
# 3      3407.52      5548.52
# 4      2211.08      9592.08
# 5      3002.07      7115.07
# 7      1245.28      3581.28
# ...        ...          ...
# 49987  4670.53      8500.53
# 49988  3578.61      6455.61
# 49990  3210.78     12370.78
# 49991  2634.55      5040.55
# 49993  2976.84      9165.84
#
# [33322 rows x 8 columns]

# %%
df[df.Escolaridade.isin(['Ensino Superior'])]
# Out:
#           Id  Idade  Renda       Sexo     Escolaridade  renda média    ativo  \
# 1          2     54   2475   Feminino  Ensino Superior     2504.530  2534.06
# 2          3     33   6820  Masculino  Ensino Superior     4926.410  3032.82
# 6          7     43   9235  Masculino  Ensino Superior     6117.055  2999.11
# 8          9     66   3783   Feminino  Ensino Superior     3900.330  4017.66
# 14        15     60   1982   Feminino  Ensino Superior     2369.625  2757.25
# ...      ...    ...    ...        ...              ...          ...      ...
# 49995  49996     41   3102   Feminino  Ensino Superior     2232.080  1362.16
# 49996  49997     33   3906   Feminino  Ensino Superior     3629.200  3352.40
# 49997  49998     41   2543  Masculino  Ensino Superior     2894.955  3246.91
# 49998  49999     22   4651   Feminino  Ensino Superior     3972.110  3293.22
# 49999  50000     22   2131   Feminino  Ensino Superior     2583.720  3036.44
#
#        renda total
# 1          5009.06
# 2          9852.82
# 6         12234.11
# 8          7800.66
# 14         4739.25
# ...            ...
# 49995      4464.16
# 49996      7258.40
# 49997      5789.91
# 49998      7944.22
# 49999      5167.44
#
# [16678 rows x 8 columns]

# %%
df.loc[~(df.Escolaridade.isin(['Ensino Superior']))]
# Out:
#           Id  Idade  Renda       Sexo        Escolaridade  renda média  \
# 0          1     27   2554   Feminino  Ensino Fundamental     3622.265
# 3          4     18   2141  Masculino        Ensino Médio     2774.260
# 4          5     67   7381  Masculino  Ensino Fundamental     4796.040
# 5          6     46   4113  Masculino  Ensino Fundamental     3557.535
# 7          8     47   2336  Masculino        Ensino Médio     1790.640
# ...      ...    ...    ...        ...                 ...          ...
# 49987  49988     41   3830  Masculino  Ensino Fundamental     4250.265
# 49988  49989     46   2877   Feminino        Ensino Médio     3227.805
# 49990  49991     47   9160  Masculino  Ensino Fundamental     6185.390
# 49991  49992     67   2406  Masculino  Ensino Fundamental     2520.275
# 49993  49994     43   6189  Masculino        Ensino Médio     4582.920
#
#          ativo  renda total
# 0      4690.53      7244.53
# 3      3407.52      5548.52
# 4      2211.08      9592.08
# 5      3002.07      7115.07
# 7      1245.28      3581.28
# ...        ...          ...
# 49987  4670.53      8500.53
# 49988  3578.61      6455.61
# 49990  3210.78     12370.78
# 49991  2634.55      5040.55
# 49993  2976.84      9165.84
#
# [33322 rows x 8 columns]

# %%
df.query("Escolaridade != 'Ensino Superior'")
# Out:
#           Id  Idade  Renda       Sexo        Escolaridade  renda média  \
# 0          1     27   2554   Feminino  Ensino Fundamental     3622.265
# 3          4     18   2141  Masculino        Ensino Médio     2774.260
# 4          5     67   7381  Masculino  Ensino Fundamental     4796.040
# 5          6     46   4113  Masculino  Ensino Fundamental     3557.535
# 7          8     47   2336  Masculino        Ensino Médio     1790.640
# ...      ...    ...    ...        ...                 ...          ...
# 49987  49988     41   3830  Masculino  Ensino Fundamental     4250.265
# 49988  49989     46   2877   Feminino        Ensino Médio     3227.805
# 49990  49991     47   9160  Masculino  Ensino Fundamental     6185.390
# 49991  49992     67   2406  Masculino  Ensino Fundamental     2520.275
# 49993  49994     43   6189  Masculino        Ensino Médio     4582.920
#
#          ativo  renda total
# 0      4690.53      7244.53
# 3      3407.52      5548.52
# 4      2211.08      9592.08
# 5      3002.07      7115.07
# 7      1245.28      3581.28
# ...        ...          ...
# 49987  4670.53      8500.53
# 49988  3578.61      6455.61
# 49990  3210.78     12370.78
# 49991  2634.55      5040.55
# 49993  2976.84      9165.84
#
# [33322 rows x 8 columns]
