# %%
import sys
sys.path.insert(0, '../')
from bibliotecas import base_estudantes, job, magalu, alunos, petrobras, sns, np, pd, plt, yf, px, go

# %%
n = 50
x= np.linspace(0,1,n)
y=np.random.normal(30,2.5,n)

# %%
linha = [go.Scatter(x=x,y=y,mode='lines')]
layout = go.Layout(title='Fig')
fig = go.Figure(data= linha, layout=layout)
fig.show()

# %%
y2 = np.random.randint(0,50,n)
y3 = np.random.uniform(0,30,n)

# %%
linhas = [go.Scatter(x=x, y=e, mode='lines', name=f'Linha {i}') for i,e in enumerate([y,y2,y3])]

# %%
go.Figure(linhas, layout=layout)
