# %%
import sys
sys.path.insert(0, '../')
from bibliotecas import base_estudantes, job, magalu, alunos, petrobras, sns, np, pd, plt, yf, px, go, sp, wn, quandl, date, db
wn.filterwarnings('ignore')

# %%
df = pd.read_excel('./Dados/Base_Dados - Estudo Combustiveis.xlsx')
preco = pd.read_csv('./Dados/Dados Preco Combutivel.csv', sep=',')

# %%
sns.pairplot(df)

# %%
df.corr()
# Out:
#                            Ano       Mes  Preco_Gasolina  Cotacao_Dolar  \
# Ano                   1.000000 -0.008518        0.913069       0.925150
# Mes                  -0.008518  1.000000        0.108296       0.095727
# Preco_Gasolina        0.913069  0.108296        1.000000       0.857412
# Cotacao_Dolar         0.925150  0.095727        0.857412       1.000000
# Acao_Petrobras        0.474461  0.070298        0.514711       0.340965
# Preco_Baril          -0.637412 -0.014328       -0.438293      -0.672238
# IPCA                 -0.203399  0.071081        0.034119      -0.005814
# Consumo_Energia(MWh)  0.558137  0.007328        0.604336       0.484536
#
#                       Acao_Petrobras  Preco_Baril      IPCA  \
# Ano                         0.474461    -0.637412 -0.203399
# Mes                         0.070298    -0.014328  0.071081
# Preco_Gasolina              0.514711    -0.438293  0.034119
# Cotacao_Dolar               0.340965    -0.672238 -0.005814
# Acao_Petrobras              1.000000     0.251181 -0.390477
# Preco_Baril                 0.251181     1.000000  0.009344
# IPCA                       -0.390477     0.009344  1.000000
# Consumo_Energia(MWh)        0.390686    -0.159431  0.028916
#
#                       Consumo_Energia(MWh)
# Ano                               0.558137
# Mes                               0.007328
# Preco_Gasolina                    0.604336
# Cotacao_Dolar                     0.484536
# Acao_Petrobras                    0.390686
# Preco_Baril                      -0.159431
# IPCA                              0.028916
# Consumo_Energia(MWh)              1.000000

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(16,9))
sns.scatterplot(data=df, x='Preco_Gasolina', y='Cotacao_Dolar', hue='Ano')
# Out:
# <AxesSubplot:xlabel='Preco_Gasolina', ylabel='Cotacao_Dolar'>

# %%
sns.lineplot(data=df, x='Data', y='Acao_Petrobras')
# Out:
# <AxesSubplot:xlabel='Data', ylabel='Acao_Petrobras'>

# %%
sns.lineplot(data=df, x='Preco_Gasolina', y='Acao_Petrobras')
# Out:
# <AxesSubplot:xlabel='Preco_Gasolina', ylabel='Acao_Petrobras'>

# %%
plt.figure(figsize=(16,9))

plt.plot(df['Data'], df['Cotacao_Dolar'], color='red')
plt.plot(df['Data'], df['Preco_Baril'])
plt.plot(df['Data'], df['Preco_Gasolina'])

# %%
df
# Out:
#       Ano  Mes       Data  Preco_Gasolina  Cotacao_Dolar  Acao_Petrobras  \
# 0    2012    1 2012-01-31        2.775390         1.8701       25.400000
# 1    2012    2 2012-02-29        2.769141         1.7448       25.600000
# 2    2012    3 2012-03-31        2.770964         1.8234       25.299999
# 3    2012    4 2012-04-30        2.769274         1.9058       23.230000
# 4    2012    5 2012-05-31        2.766385         2.0873       21.400000
# ..    ...  ...        ...             ...            ...             ...
# 113  2021    8 2021-08-31        5.921173         5.4141       29.350000
# 114  2021    9 2021-09-30        6.083662         5.4417       27.389999
# 115  2021   10 2021-10-31        6.337462         5.6578       29.680000
# 116  2021   11 2021-11-30        6.741298         5.6789       29.620001
# 117  2021   12 2021-12-31        6.674896         5.7440       29.690001
#
#      Preco_Baril   IPCA  Consumo_Energia(MWh)
# 0     113.699997   6.22          3.630517e+07
# 1     125.470001   5.85          3.690053e+07
# 2     126.220001   5.24          3.862311e+07
# 3     125.430000   5.10          3.799587e+07
# 4     119.660004   4.99          3.681019e+07
# ..           ...    ...                   ...
# 113    73.410004   9.68          4.062858e+07
# 114    79.529999  10.25          4.198532e+07
# 115    86.400002  10.67          4.262215e+07
# 116    84.779999  10.74          4.193184e+07
# 117    79.320000  10.06          4.293671e+07
#
# [118 rows x 9 columns]

# %%
plt.figure(figsize=(16,9))
sns.lineplot(data=df.query('2020<=Ano<=2022'), x='Data', y='Consumo_Energia(MWh)')
# Out:
# <AxesSubplot:xlabel='Data', ylabel='Consumo_Energia(MWh)'>

# %%
plt.subplots(2,1)

plt.subplot(2,1,1)
sns.lineplot(data=df.query('2020<=Ano<=2022'), x='Data', y='Consumo_Energia(MWh)')

plt.subplot(2,1,2).set_axis_off() #remove o box de figura
plt.annotate('meu texto', xy=(0.4, 0.1), xycoords='axes fraction')
# Out:
# Text(0.4, 0.1, 'meu texto')
