# %%
import numpy as np 
import pandas as pd

# %%
np.random.seed(10)
# quantidade de observações
n = 100

escolaridade = ['Ensino Fundamental', 'Ensino Médio', 'Ensino Superior']

cidades = ['São Paulo', 'Recife', 'Salvador', 'Salvador', 'Rio de Janeiro']

sexo = ['Masculino', 'Feminino']


# dicionário com dados
data = {
    'Id': np.arange(1, n+1),
    'Idade': np.random.randint(18, 70, size = n),
    'Renda': np.random.randint(1_500, 10_000, size = n),
    'Sexo': np.random.choice(sexo, size = n),
    'Escolaridade': np.random.choice(escolaridade, size = n),
    'Cidade': np.random.choice(cidades, size = n)
}

df = pd.DataFrame(data)

# %%
df.to_excel('dados.xlsx', index=False)

# %%
import sqlite3

# %%
connect = sqlite3.connect('base.db') #cria base e se conecta

# %%
df.to_sql(name='base', con=connect, index=False)
# Out:
# 100

# %%
pd.read_sql_query('SELECT idade FROM base', connect)
# Out:
#     Idade
# 0      27
# 1      54
# 2      33
# 3      18
# 4      67
# ..    ...
# 95     67
# 96     33
# 97     62
# 98     58
# 99     60
#
# [100 rows x 1 columns]

# %%
pd.read_sql_query('SELECT * FROM base WHERE idade > 30', connect)
# Out:
#      Id  Idade  Renda       Sexo        Escolaridade          Cidade
# 0     2     54   7957   Feminino     Ensino Superior          Recife
# 1     3     33   6343   Feminino  Ensino Fundamental        Salvador
# 2     5     67   4105   Feminino  Ensino Fundamental          Recife
# 3     6     46   9345  Masculino     Ensino Superior       São Paulo
# 4     7     43   2414   Feminino        Ensino Médio       São Paulo
# ..  ...    ...    ...        ...                 ...             ...
# 72   96     67   2958  Masculino        Ensino Médio          Recife
# 73   97     33   5068  Masculino     Ensino Superior          Recife
# 74   98     62   7176  Masculino        Ensino Médio        Salvador
# 75   99     58   2375   Feminino     Ensino Superior  Rio de Janeiro
# 76  100     60   4265  Masculino  Ensino Fundamental        Salvador
#
# [77 rows x 6 columns]

# %%
dados = pd.read_csv('../Pandas/StudentsPerformance.csv')

# %%
dados
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
provas = ['math score',	'reading score',	'writing score']

# %%
dados['media'] = dados[provas].mean(axis=1)

# %%
dados
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
dados.groupby(by='gender')['math score'].mean()
# Out:
# gender
# female    63.633205
# male      68.728216
# Name: math score, dtype: float64

# %%
dados.groupby(by='gender')['math score'].describe()
# Out:
#         count       mean        std   min   25%   50%   75%    max
# gender
# female  518.0  63.633205  15.491453   0.0  54.0  65.0  74.0  100.0
# male    482.0  68.728216  14.356277  27.0  59.0  69.0  79.0  100.0

# %%
dados.groupby(by='gender')['math score'].agg([min, np.mean, np.median, max])
# Out:
#         min       mean  median  max
# gender
# female    0  63.633205    65.0  100
# male     27  68.728216    69.0  100

# %%
dados.groupby(by=['gender', 'lunch'])[['math score','reading score']].agg([min, np.mean, np.median, max])
# Out:
#                     math score                        reading score  \
#                            min       mean median  max           min
# gender lunch
# female free/reduced          0  55.814815   57.0   93            17
#        standard             19  68.124620   67.0  100            29
# male   free/reduced         27  62.457831   62.0  100            23
#        standard             30  72.022152   72.0  100            26
#
#
#                           mean median  max
# gender lunch
# female free/reduced  67.386243   67.0  100
#        standard      75.607903   75.0  100
# male   free/reduced  61.542169   61.0  100
#        standard      67.537975   67.5  100
