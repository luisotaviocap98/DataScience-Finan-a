# %%
import sys
sys.path.insert(0, '../')
from bibliotecas import base_estudantes, job, magalu, alunos, petrobras, sns, np, pd, plt, yf, px, go, sp, wn, quandl, date, db
wn.filterwarnings('ignore')

# %%
df = pd.read_csv('novos_dados.csv')

# %%
df
# Out:
#       Unnamed: 0 SG_UF_RESIDENCIA  NU_IDADE  TP_ESCOLA Q006  NU_NOTA_CN  \
# 0              0               RJ        18          2    C       377.3
# 1              1               RJ        18          2    C       572.8
# 2              2               RJ        18          2    C       378.0
# 3              3               RJ        18          2    C       598.6
# 4              4               RJ        17          2    C       534.1
# ...          ...              ...       ...        ...  ...         ...
# 9965        9965               ES        17          3    N       605.2
# 9966        9966               MT        17          3    N       543.2
# 9967        9967               MT        17          3    N       543.8
# 9968        9968               MT        17          3    N       535.8
# 9969        9969               MT        18          3    N       614.6
#
#       NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_MT  NU_NOTA_REDACAO        Região  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9970 entries, 0 to 9969
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        9970 non-null   int64
#  1   SG_UF_RESIDENCIA  9970 non-null   object
#  2   NU_IDADE          9970 non-null   int64
#  3   TP_ESCOLA         9970 non-null   int64
#  4   Q006              9970 non-null   object
#  5   NU_NOTA_CN        9970 non-null   float64
#  6   NU_NOTA_CH        9970 non-null   float64
#  7   NU_NOTA_LC        9970 non-null   float64
#  8   NU_NOTA_MT        9970 non-null   float64
#  9   NU_NOTA_REDACAO   9970 non-null   int64
#  10  Região            9970 non-null   object
#  11  Opção             9970 non-null   object
#  12  Renda             9970 non-null   object
#  13  NovaRenda         9970 non-null   float64
# dtypes: float64(5), int64(4), object(5)
# memory usage: 1.1+ MB

# %%
plt.figure(figsize=(15,10))
sns.boxplot(data=df, x='NovaRenda',y='NU_NOTA_MT')
# Out:
# <AxesSubplot:xlabel='NovaRenda', ylabel='NU_NOTA_MT'>

# %%
plt.figure(figsize=(15,10))
sns.lineplot(data=df, x='NovaRenda',y='NU_NOTA_MT')
# Out:
# <AxesSubplot:xlabel='NovaRenda', ylabel='NU_NOTA_MT'>

# %%
df
# Out:
#       Unnamed: 0 SG_UF_RESIDENCIA  NU_IDADE  TP_ESCOLA Q006  NU_NOTA_CN  \
# 0              0               RJ        18          2    C       377.3
# 1              1               RJ        18          2    C       572.8
# 2              2               RJ        18          2    C       378.0
# 3              3               RJ        18          2    C       598.6
# 4              4               RJ        17          2    C       534.1
# ...          ...              ...       ...        ...  ...         ...
# 9965        9965               ES        17          3    N       605.2
# 9966        9966               MT        17          3    N       543.2
# 9967        9967               MT        17          3    N       543.8
# 9968        9968               MT        17          3    N       535.8
# 9969        9969               MT        18          3    N       614.6
#
#       NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_MT  NU_NOTA_REDACAO        Região  \
# ...

# %%
df.groupby('Região').mean()['NU_NOTA_MT'].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Região'>

# %%
sns.barplot(df.groupby('Região').mean()['NU_NOTA_MT'].index, df.groupby('Região').mean()['NU_NOTA_MT']);
