# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import yfinance as yf

# %%
n = np.random.randint(1,100,10)

# %%
n
# Out:
# array([30, 67, 69, 71, 32, 91, 28, 72, 92, 42])

# %%
plt.plot(n, marker='o', linestyle='--')
plt.grid(axis='y')

# %%
plt.plot(n,'o--k') #fmt

# %%
mag = yf.Ticker('MGLU3.SA').history(period='max')

# %%
plt.plot(mag.index, mag.Close)
plt.xlim([mag.index.min(), mag.index.max()])
# Out:
# (15096.0, 19185.0)

# %%
m = mag.resample('Y').mean()

# %%
plt.bar(m.Close.index.year, m.Close.values)
# Out:
# <BarContainer object of 12 artists>

# %%
x= np.random.normal(10,0.5,100)
y=np.random.uniform(0,20,100)

# %%
# scatter para relacao entre variaveis
plt.scatter(x,y)
