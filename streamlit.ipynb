# %%
import sys
sys.path.insert(0, '../')
from bibliotecas import base_estudantes, job, magalu, alunos, petrobras, sns, np, pd, plt, yf, px, go, sp, wn, quandl, date, db, geobr, gpd, os
wn.filterwarnings('ignore')

# %%
df = magalu()

# %%
import pmdarima

# %%
btc = yf.Ticker('BTC-USD').history(period='max')[['Open', 'Close', 'High', 'Low', 'Volume']]

# %%
btc
# Out:
#                     Open         Close          High           Low  \
# Date
# 2014-09-17    465.864014    457.334015    468.174011    452.421997
# 2014-09-18    456.859985    424.440002    456.859985    413.104004
# 2014-09-19    424.102997    394.795990    427.834991    384.532013
# 2014-09-20    394.673004    408.903992    423.295990    389.882996
# 2014-09-21    408.084991    398.821014    412.425995    393.181000
# ...                  ...           ...           ...           ...
# 2022-07-21  23233.201172  23164.628906  23388.322266  22431.148438
# 2022-07-22  23163.751953  22714.978516  23671.927734  22603.416016
# 2022-07-23  22706.984375  22465.478516  22977.210938  22002.910156
# 2022-07-24  22465.509766  22609.164062  22974.001953  22306.839844
# 2022-07-25  22607.156250  21361.701172  22649.121094  21361.642578
#
#                  Volume
# Date
# 2014-09-17     21056800
# 2014-09-18     34483200
# 2014-09-19     37919700
# 2014-09-20     36863600
# 2014-09-21     26580100
# ...                 ...
# 2022-07-21  33631012204
# 2022-07-22  31421555646
# 2022-07-23  24021799169
# 2022-07-24  23565495303
# 2022-07-25  35574561406
#
# [2869 rows x 5 columns]

# %%
temp = btc['2021-1-1':]

# %%
f = go.Figure(data=[
    go.Candlestick(
        x=temp.index,
        open= temp['Open'],
        high=temp['High'],
        low=temp['Low'],
        close=temp['Close'],
        showlegend=False
    )
])

lay = go.Layout(
    yaxis_tickformat='$',
    xaxis=dict(rangeslider=dict(visible=False))
)

f.update_layout(lay)

f.show()

# %%
import streamlit as st

# %%
moving = temp.rolling(2).mean()

# %%
f = go.Figure(data=[go.Scatter(
                x=moving.index,
                y=moving['Open'].values
            )
])
f.show()

# %%
# outra opcao de criar site de dados eh o plotly dash
